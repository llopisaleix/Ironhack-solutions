# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
# Why this strange 'fromdate'? Can we use normal date format?
#https://api.stackexchange.com/docs/dates
questions = SITE.fetch('questions', fromdate=1585699200, todate=1588291200)
answers = SITE.fetch('answers', fromdate=1585699200, todate=1588291200)
print(questions)
print(answers)
#https://api.stackexchange.com/docs/questions
# Out:
# {'backoff': 0, 'has_more': True, 'page': 5, 'quota_max': 300, 'quota_remaining': 300, 'total': 0, 'items': [{'tags': ['ios', 'swift', 'label', 'collectionview'], 'owner': {'reputation': 60, 'user_id': 9109811, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/69e276d8dfbf97b26369ea5b7ea00057?s=128&d=identicon&r=PG&f=1', 'display_name': 'Ghassan', 'link': 'https://stackoverflow.com/users/9109811/ghassan'}, 'is_answered': False, 'view_count': 147, 'answer_count': 1, 'score': 0, 'last_activity_date': 1589964971, 'creation_date': 1586602110, 'last_edit_date': 1589964971, 'question_id': 61155553, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/61155553/fill-in-blank-from-collectionview-cell', 'title': 'Fill in blank from CollectionView Cell'}, {'tags': ['google-cloud-platform', 'google-bigquery', 'grafana', 'stackdriver', 'google-cloud-stackdriver'], 'owner': {'reputation': 3111, 'user_id': 7252805, 'user_type': 'registered', 'accept_rate': 97, 'profile_image': 'https://i.stack.imgur.com/7x3Z0.png?s=128&g=1', 'display_name': 'sheldonzy', 'link': 'https://stackoverflow.com/users/7252805/sheldonzy'}, 'is_answered': False, 'view_count': 42, 'answer_count': 0, 'score': 1, 'last_activity_date': 1589964572, 'creation_date': 1587895337, 'last_edit_date': 1589964572, 'question_id': 61438914, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/61438914/bigquery-monitoring-using-grafana-via-stackdriver-no-data-for-some-metrics-li', 'title': 'BigQuery monitoring using Grafana via Stackdriver - no data for some metrics (like &quot;uploaded bytes&quot;)'}, {'tags': ['node.js', 'amazon-elastic-beanstalk'], 'owner': {'reputation': 2560, 'user_id': 1323517, 'user_type': 'registered', 'accept_rate': 69, 'profile_image': 'https://i.stack.imgur.com/kx0SU.jpg?s=128&g=1', 'display_name': 'comiventor', 'link': 'https://stackoverflow.com/users/1323517/comiventor'}, 'is_answered': True, 'view_count': 21, 'accepted_answer_id': 61558849, 'answer_count': 1, 'score': 0, 'last_activity_date': 1589963475, 'creation_date': 1587640987, 'last_edit_date': 1589963475, 'question_id': 61386045, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/61386045/no-data-health-status-while-deploying-node-app-via-beanstalk', 'title': '&quot;no data&quot; health status while deploying node app via beanstalk'}, {'tags': ['javascript', 'python', 'jquery', 'ajax', 'flask'], 'owner': {'reputation': 1, 'user_id': 9874065, 'user_type': 'registered', 'profile_image': 'https://i.stack.imgur.com/FAJui.jpg?s=128&g=1', 'display_name': 'Arun Chauhan', 'link': 'https://stackoverflow.com/users/9874065/arun-chauhan'}, 'is_answered': False, 'view_count': 26, 'answer_count': 0, 'score': 0, 'last_activity_date': 1589963466, 'creation_date': 1588224514, 'last_edit_date': 1589963466, 'question_id': 61516487, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/61516487/page-stops-responding-and-freezes-while-sending-continuous-request-to-web-server', 'title': 'Page stops responding and freezes while sending continuous request to web server from ajax'}, {'tags': ['bash', 'bash-trap'], 'owner': {'reputation': 11, 'user_id': 13217377, 'user_type': 'registered', 'profile_image': 'https://i.stack.imgur.com/q4k2o.jpg?s=128&g=1', 'display_name': 'Rebelion', 'link': 'https://stackoverflow.com/users/13217377/rebelion'}, 'is_answered': False, 'view_count': 42, 'answer_count': 1, 'score': 1, 'last_activity_date': 1589963233, 'creation_date': 1585968256, 'last_edit_date': 1585972581, 'question_id': 61023171, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/61023171/bash-trap-sigint-multiple-times-doesnt-work', 'title': 'Bash Trap SIGINT Multiple Times Doesn&#39;t Work'}, {'tags': ['vuetify.js'], 'owner': {'reputation': 357, 'user_id': 1098303, 'user_type': 'registered', 'accept_rate': 70, 'profile_image': 'https://i.stack.imgur.com/4TxaL.p ...
# {'backoff': 0, 'has_more': True, 'page': 5, 'quota_max': 300, 'quota_remaining': 300, 'total': 0, 'items': [{'owner': {'reputation': 47282, 'user_id': 4653379, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/b3953dbedd0dabff5cbc3db9b0835b14?s=128&d=identicon&r=PG&f=1', 'display_name': 'zdim', 'link': 'https://stackoverflow.com/users/4653379/zdim'}, 'is_accepted': True, 'score': 5, 'last_activity_date': 1589961223, 'last_edit_date': 1589961223, 'creation_date': 1588139380, 'answer_id': 61495101, 'question_id': 61494519, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 47282, 'user_id': 4653379, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/b3953dbedd0dabff5cbc3db9b0835b14?s=128&d=identicon&r=PG&f=1', 'display_name': 'zdim', 'link': 'https://stackoverflow.com/users/4653379/zdim'}, 'is_accepted': False, 'score': 9, 'last_activity_date': 1589960746, 'last_edit_date': 1589960746, 'creation_date': 1588022855, 'answer_id': 61468748, 'question_id': 61467672, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 1095, 'user_id': 6541218, 'user_type': 'registered', 'profile_image': 'https://i.stack.imgur.com/Otii5.jpg?s=128&g=1', 'display_name': 'Mayur', 'link': 'https://stackoverflow.com/users/6541218/mayur'}, 'is_accepted': False, 'score': 8, 'last_activity_date': 1589960682, 'last_edit_date': 1589960682, 'creation_date': 1586927301, 'answer_id': 61221726, 'question_id': 3327312, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 141, 'user_id': 11345174, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/9255bd76e7c539eb05abf3a28d0ab088?s=128&d=identicon&r=PG&f=1', 'display_name': 'Paul A', 'link': 'https://stackoverflow.com/users/11345174/paul-a'}, 'is_accepted': True, 'score': 0, 'last_activity_date': 1589958028, 'last_edit_date': 1589958028, 'creation_date': 1585902520, 'answer_id': 61007854, 'question_id': 60951358, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 2085, 'user_id': 1490257, 'user_type': 'registered', 'accept_rate': 75, 'profile_image': 'https://www.gravatar.com/avatar/f0d1397e6c2d3e9c186c571c48801f86?s=128&d=identicon&r=PG', 'display_name': 'Pete Fordham', 'link': 'https://stackoverflow.com/users/1490257/pete-fordham'}, 'is_accepted': True, 'score': 1, 'last_activity_date': 1589956511, 'last_edit_date': 1589956511, 'creation_date': 1587447455, 'answer_id': 61336634, 'question_id': 21963658, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 413, 'user_id': 542911, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/6d867a254338694687e161af3036842e?s=128&d=identicon&r=PG', 'display_name': 'Regan Sarwas', 'link': 'https://stackoverflow.com/users/542911/regan-sarwas'}, 'is_accepted': False, 'score': 1, 'last_activity_date': 1589956492, 'last_edit_date': 1589956492, 'creation_date': 1587522278, 'answer_id': 61356269, 'question_id': 46999079, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 684, 'user_id': 10463261, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/e5f36968922a93930e4ae8259f8cacaf?s=128&d=identicon&r=PG', 'display_name': 'Daniel Morell', 'link': 'https://stackoverflow.com/users/10463261/daniel-morell'}, 'is_accepted': True, 'score': 1, 'last_activity_date': 1589956486, 'last_edit_date': 1589956486, 'creation_date': 1587645320, 'answer_id': 61387369, 'question_id': 61387038, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 700, 'user_id': 3937773, 'user_type': 'registered', 'accept_rate': 43, 'profile_image': 'https://i.stack.imgur.com/4orvN.jpg?s=128&g=1', 'display_name': 'Eric Ihli', 'link': 'https://stackoverflow.com/users/3937773/eric-ihli'}, 'is_accepted': True, 'score': 3, 'last_activity_date': 1589956478, 'last_edit_date': 1589956478, 'creation_date': 1587844236, 'answer_id': 61431697, 'question_id': 47533875, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 21, 'user_id': 95 ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
# Why do we sort by votes and not by 'score'? 
voted_question = SITE.fetch('questions', fromdate=1585699200, todate=1588291200, min=5, tagged='python', sort='votes')['items']
voted_question[0]
# Out:
# {'tags': ['python', 'python-internals'],
#  'owner': {'reputation': 710,
#   'user_id': 13313873,
#   'user_type': 'registered',
#   'profile_image': 'https://www.gravatar.com/avatar/6aa6b50fa640d12712242fe7ea1f60c7?s=128&d=identicon&r=PG&f=1',
#   'display_name': 'noob overflow',
#   'link': 'https://stackoverflow.com/users/13313873/noob-overflow'},
#  'is_answered': True,
#  'view_count': 3142,
#  'accepted_answer_id': 61221502,
#  'answer_count': 4,
#  'score': 70,
#  'last_activity_date': 1587612666,
#  'creation_date': 1586886039,
#  'last_edit_date': 1586967663,
#  'question_id': 61213866,
#  'content_license': 'CC BY-SA 4.0',
#  'link': 'https://stackoverflow.com/questions/61213866/why-do-i-get-this-many-iterations-when-adding-to-and-removing-from-a-set-while-i',
#  'title': 'Why do I get this many iterations when adding to and removing from a set while iterating over it?'}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
answers = SITE.fetch('answers/{ids}',ids=[6784,6743], filter='withbody')

# %%
print(answers)
# Out:
# {'backoff': 0, 'has_more': False, 'page': 1, 'quota_max': 300, 'quota_remaining': 300, 'total': 0, 'items': [{'owner': {'reputation': 28815, 'user_id': 758, 'user_type': 'registered', 'accept_rate': 77, 'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG', 'display_name': 'Mark Renouf', 'link': 'https://stackoverflow.com/users/758/mark-renouf'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1218291583, 'creation_date': 1218291583, 'answer_id': 6784, 'question_id': 6778, 'content_license': 'CC BY-SA 2.5', 'body': "<p>Enabling windowless mode (wmode=) makes embedded flash act and render just like other elements. Without that, it's rendered in a seperate step and just overlaid on the browser's window.</p>\n\n<p>Could the flash element be losing focus? Sounds like input focus is moved to the scollbar, then you have to move it back.</p>\n\n<p>Also you weren't clear whether the focus issue was only in FF or also in IE.</p>\n"}]}
